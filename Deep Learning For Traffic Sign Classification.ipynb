# %% [markdown]
# ### IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# ### PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 10

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 10
L_grid = 10

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid*L_grid):
    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index], fontsize= 15)
    axes[i].axis('off')
    
plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[-0.73958333],
#          [-0.71614583],
#          [-0.69791667],
#          ...,
#          [-0.66927083],
#          [-0.69010417],
#          [-0.71614583]],
#
#         [[-0.73697917],
#          [-0.7109375 ],
#          [-0.68489583],
#          ...,
#          [-0.640625  ],
#          [-0.63020833],
#          [-0.6640625 ]],
#
#         [[-0.74739583],
#          [-0.7265625 ],
#          [-0.70833333],
#          ...,
#          [-0.62239583],
#          [-0.62239583],
#          [-0.6328125 ]],
#
#         ...,
#
#         [[-0.703125  ],
#          [-0.73697917],
#          [-0.765625  ],
#          ...,
#          [-0.69270833],
#          [-0.71354167],
#          [-0.73958333]],
#
#         [[-0.67447917],
#          [-0.70833333],
#          [-0.734375  ],
#          ...,
#          [-0.69791667],
#          [-0.71875   ],
#          [-0.7421875 ]],
#
#         [[-0.70052083],
#          [-0.69270833],
#          [-0.7109375 ],
#          ...,
#          [-0.70572917],
#          [-0.72395833],
#          [-0.73177083]]],
#
#
#        [[[-0.83333333],
#          [-0.9140625 ],
#          [-0.91927083],
#          ...,
#          [-0.4609375 ],
#          [-0.6953125 ],
#          [-0.83854167]],
#
#         [[-0.81510417],
#          [-0.8984375 ],
#          [-0.9140625 ],
#          ...,
#          [-0.58333333],
#          [-0.80729167],
#          [-0.85677083]],
#
#         [[-0.85677083],
#          [-0.8984375 ],
#          [-0.91927083],
#          ...,
#          [-0.79427083],
#          [-0.796875  ],
#          [-0.85677083]],
#
#         ...,
#
#         [[-0.9296875 ],
#          [-0.921875  ],
#          [-0.9296875 ],
#          ...,
#          [-0.91666667],
#          [-0.921875  ],
#          [-0.92447917]],
#
#         [[-0.93229167],
#          [-0.93489583],
#          [-0.93229167],
#          ...,
#          [-0.921875  ],
#          [-0.92447917],
#          [-0.92447917]],
#
#         [[-0.93229167],
#          [-0.93489583],
#          [-0.92708333],
#          ...,
#          [-0.91927083],
#          [-0.91666667],
#          [-0.92447917]]],
#
#
#        [[[-0.62239583],
#          [-0.62760417],
#          [-0.4765625 ],
#          ...,
#          [-0.31510417],
#          [-0.51822917],
#          [-0.56510417]],
#
#         [[-0.60677083],
#          [-0.640625  ],
#          [-0.57291667],
#          ...,
#          [-0.515625  ],
#          [-0.61458333],
#          [-0.30729167]],
#
#         [[-0.65885417],
#          [-0.66927083],
#          [-0.6796875 ],
#          ...,
#          [-0.6640625 ],
#          [-0.61979167],
#          [-0.19270833]],
#
#         ...,
#
#         [[-0.7265625 ],
#          [-0.70052083],
#          [-0.58854167],
#          ...,
#          [-0.578125  ],
#          [-0.5390625 ],
#          [-0.44270833]],
#
#         [[-0.69010417],
#          [-0.68229167],
#          [-0.59375   ],
#          ...,
#          [-0.59375   ],
#          [-0.4296875 ],
#          [-0.25520833]],
#
#         [[-0.703125  ],
#          [-0.69010417],
#          [-0.61197917],
#          ...,
#          [-0.51822917],
#          [-0.13802083],
#          [ 0.26302083]]],
#
#
#        ...,
#
#
#        [[[-0.84635417],
#          [-0.8515625 ],
#          [-0.84375   ],
#          ...,
#          [-0.859375  ],
#          [-0.85677083],
#          [-0.875     ]],
#
#         [[-0.84114583],
#          [-0.85677083],
#          [-0.83854167],
#          ...,
#          [-0.86197917],
#          [-0.84375   ],
#          [-0.8671875 ]],
#
#         [[-0.8515625 ],
#          [-0.85677083],
#          [-0.859375  ],
#          ...,
#          [-0.86197917],
#          [-0.85677083],
#          [-0.859375  ]],
#
#         ...,
#
#         [[-0.87760417],
#          [-0.87760417],
#          [-0.8828125 ],
#          ...,
#          [-0.88541667],
#          [-0.89322917],
#          [-0.890625  ]],
#
#         [[-0.875     ],
#          [-0.87760417],
#          [-0.875     ],
#          ...,
#          [-0.89583333],
#          [-0.89322917],
#          [-0.890625  ]],
#
#         [[-0.8671875 ],
#          [-0.87760417],
#          [-0.86979167],
#          ...,
#          [-0.90104167],
#          [-0.890625  ],
#          [-0.890625  ]]],
#
#
#        [[[-0.8671875 ],
#          [-0.86197917],
#          [-0.84635417],
#          ...,
#          [-0.85677083],
#          [-0.875     ],
#          [-0.88020833]],
#
#         [[-0.85677083],
#          [-0.84114583],
#          [-0.83854167],
#          ...,
#          [-0.85416667],
#          [-0.85677083],
#          [-0.85677083]],
#
#         [[-0.86458333],
#          [-0.828125  ],
#          [-0.84375   ],
#          ...,
#          [-0.859375  ],
#          [-0.84895833],
#          [-0.85677083]],
#
#         ...,
#
#         [[-0.84114583],
#          [-0.8515625 ],
#          [-0.85416667],
#          ...,
#          [-0.890625  ],
#          [-0.89583333],
#          [-0.89583333]],
#
#         [[-0.84114583],
#          [-0.84895833],
#          [-0.8515625 ],
#          ...,
#          [-0.89322917],
#          [-0.88802083],
#          [-0.89583333]],
#
#         [[-0.84375   ],
#          [-0.8515625 ],
#          [-0.85677083],
#          ...,
#          [-0.88802083],
#          [-0.890625  ],
#          [-0.8984375 ]]],
#
#
#        [[[-0.34635417],
#          [-0.640625  ],
#          [-0.7421875 ],
#          ...,
#          [-0.67708333],
#          [-0.58072917],
#          [-0.44270833]],
#
#         [[-0.48958333],
#          [-0.65625   ],
#          [-0.734375  ],
#          ...,
#          [-0.71875   ],
#          [-0.7265625 ],
#          [-0.66927083]],
#
#         [[-0.6171875 ],
#          [-0.72916667],
#          [-0.78645833],
#          ...,
#          [-0.6171875 ],
#          [-0.63541667],
#          [-0.65104167]],
#
#         ...,
#
#         [[ 0.68229167],
#          [ 0.66145833],
#          [ 0.43229167],
#          ...,
#          [-0.5546875 ],
#          [-0.7265625 ],
#          [-0.6953125 ]],
#
#         [[ 0.7265625 ],
#          [ 0.66666667],
#          [ 0.57291667],
#          ...,
#          [-0.5859375 ],
#          [-0.65364583],
#          [-0.74739583]],
#
#         [[ 0.76041667],
#          [ 0.63802083],
#          [ 0.7109375 ],
#          ...,
#          [-0.5       ],
#          [-0.57552083],
#          [-0.72916667]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# ### BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(32,(5,5), activation = 'relu', input_shape = (32, 32, 1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Dropout(0.2))

CNN.add(layers.Conv2D(64,(5,5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation = 'relu'))
CNN.add(layers.Dense(84, activation = 'relu'))
CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_45 (Conv2D)           (None, 28, 28, 32)        832
# _________________________________________________________________
# average_pooling2d_45 (Averag (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 10, 10, 64)        51264
# _________________________________________________________________
# average_pooling2d_46 (Averag (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 120)               192120
# _________________________________________________________________
# dense_28 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dense_29 (Dense)             (None, 43)                3655
# =================================================================
# Total params: 258,035
# Trainable params: 258,035
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm,
                 y_train,
                 batch_size = 500,
                 epochs = 50,
                 verbose = 1,
                 validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 24s 687us/sample - loss: 2.7771 - accuracy: 0.2756 - val_loss: 1.7862 - val_accuracy: 0.4977
# Epoch 2/50
# 34799/34799 [==============================] - 25s 729us/sample - loss: 1.0510 - accuracy: 0.7004 - val_loss: 0.8642 - val_accuracy: 0.7397
# Epoch 3/50
# 34799/34799 [==============================] - 22s 636us/sample - loss: 0.5826 - accuracy: 0.8390 - val_loss: 0.6791 - val_accuracy: 0.7800
# Epoch 4/50
# 34799/34799 [==============================] - 29s 838us/sample - loss: 0.4039 - accuracy: 0.8898 - val_loss: 0.5923 - val_accuracy: 0.8238
# Epoch 5/50
# 34799/34799 [==============================] - 25s 723us/sample - loss: 0.3058 - accuracy: 0.9183 - val_loss: 0.4727 - val_accuracy: 0.8540
# Epoch 6/50
# 34799/34799 [==============================] - 23s 648us/sample - loss: 0.2379 - accuracy: 0.9381 - val_loss: 0.4472 - val_accuracy: 0.8773
# Epoch 7/50
# 34799/34799 [==============================] - 24s 682us/sample - loss: 0.1939 - accuracy: 0.9487 - val_loss: 0.4318 - val_accuracy: 0.8837
# Epoch 8/50
# 34799/34799 [==============================] - 24s 704us/sample - loss: 0.1610 - accuracy: 0.9580 - val_loss: 0.4015 - val_accuracy: 0.8871
# Epoch 9/50
# 34799/34799 [==============================] - 22s 638us/sample - loss: 0.1427 - accuracy: 0.9622 - val_loss: 0.3899 - val_accuracy: 0.8930
# Epoch 10/50
# 34799/34799 [==============================] - 22s 619us/sample - loss: 0.1171 - accuracy: 0.9715 - val_loss: 0.4035 - val_accuracy: 0.8977
# Epoch 11/50
# 34799/34799 [==============================] - 23s 649us/sample - loss: 0.1049 - accuracy: 0.9725 - val_loss: 0.4048 - val_accuracy: 0.8975
# Epoch 12/50
# 34799/34799 [==============================] - 27s 765us/sample - loss: 0.0891 - accuracy: 0.9771 - val_loss: 0.3966 - val_accuracy: 0.8941
# Epoch 13/50
# 34799/34799 [==============================] - 26s 754us/sample - loss: 0.0800 - accuracy: 0.9796 - val_loss: 0.3844 - val_accuracy: 0.9032
# Epoch 14/50
# 34799/34799 [==============================] - 23s 649us/sample - loss: 0.0718 - accuracy: 0.9810 - val_loss: 0.3649 - val_accuracy: 0.9093
# Epoch 15/50
# 34799/34799 [==============================] - 22s 639us/sample - loss: 0.0644 - accuracy: 0.9832 - val_loss: 0.3989 - val_accuracy: 0.9005
# Epoch 16/50
# 34799/34799 [==============================] - 22s 621us/sample - loss: 0.0604 - accuracy: 0.9843 - val_loss: 0.3874 - val_accuracy: 0.9043
# Epoch 17/50
# 34799/34799 [==============================] - 23s 653us/sample - loss: 0.0530 - accuracy: 0.9861 - val_loss: 0.3983 - val_accuracy: 0.9032
# Epoch 18/50
# 34799/34799 [==============================] - 22s 633us/sample - loss: 0.0467 - accuracy: 0.9879 - val_loss: 0.4200 - val_accuracy: 0.9048
# Epoch 19/50
# 34799/34799 [==============================] - 23s 653us/sample - loss: 0.0423 - accuracy: 0.9889 - val_loss: 0.4002 - val_accuracy: 0.9091
# Epoch 20/50
# 34799/34799 [==============================] - 21s 613us/sample - loss: 0.0369 - accuracy: 0.9912 - val_loss: 0.3689 - val_accuracy: 0.9127
# Epoch 21/50
# 34799/34799 [==============================] - 22s 644us/sample - loss: 0.0332 - accuracy: 0.9920 - val_loss: 0.4273 - val_accuracy: 0.9007
# Epoch 22/50
# 34799/34799 [==============================] - 25s 704us/sample - loss: 0.0332 - accuracy: 0.9918 - val_loss: 0.3945 - val_accuracy: 0.9138
# Epoch 23/50
# 34799/34799 [==============================] - 24s 680us/sample - loss: 0.0310 - accuracy: 0.9916 - val_loss: 0.4657 - val_accuracy: 0.8998
# Epoch 24/50
# 34799/34799 [==============================] - 21s 604us/sample - loss: 0.0308 - accuracy: 0.9916 - val_loss: 0.4074 - val_accuracy: 0.9188
# Epoch 25/50
# 34799/34799 [==============================] - 22s 645us/sample - loss: 0.0241 - accuracy: 0.9935 - val_loss: 0.4307 - val_accuracy: 0.9011
# Epoch 26/50
# 34799/34799 [==============================] - 22s 619us/sample - loss: 0.0217 - accuracy: 0.9946 - val_loss: 0.3750 - val_accuracy: 0.9268
# Epoch 27/50
# 34799/34799 [==============================] - 21s 599us/sample - loss: 0.0197 - accuracy: 0.9948 - val_loss: 0.4077 - val_accuracy: 0.9138
# Epoch 28/50
# 34799/34799 [==============================] - 22s 639us/sample - loss: 0.0205 - accuracy: 0.9948 - val_loss: 0.4228 - val_accuracy: 0.9095
# Epoch 29/50
# 34799/34799 [==============================] - 20s 573us/sample - loss: 0.0244 - accuracy: 0.9936 - val_loss: 0.3759 - val_accuracy: 0.9234
# Epoch 30/50
# 34799/34799 [==============================] - 21s 602us/sample - loss: 0.0163 - accuracy: 0.9959 - val_loss: 0.3959 - val_accuracy: 0.9190
# Epoch 31/50
# 34799/34799 [==============================] - 22s 625us/sample - loss: 0.0197 - accuracy: 0.9946 - val_loss: 0.4170 - val_accuracy: 0.9134
# Epoch 32/50
# 34799/34799 [==============================] - 23s 664us/sample - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.4305 - val_accuracy: 0.9059
# Epoch 33/50
# 34799/34799 [==============================] - 22s 619us/sample - loss: 0.0155 - accuracy: 0.9959 - val_loss: 0.4238 - val_accuracy: 0.9073
# Epoch 34/50
# 34799/34799 [==============================] - 22s 643us/sample - loss: 0.0149 - accuracy: 0.9959 - val_loss: 0.3946 - val_accuracy: 0.9147
# Epoch 35/50
# 34799/34799 [==============================] - 20s 578us/sample - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.3696 - val_accuracy: 0.9270
# Epoch 36/50
# 34799/34799 [==============================] - 20s 566us/sample - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.4694 - val_accuracy: 0.9150
# Epoch 37/50
# 34799/34799 [==============================] - 20s 574us/sample - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.3449 - val_accuracy: 0.9290
# Epoch 38/50
# 34799/34799 [==============================] - 22s 625us/sample - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.3991 - val_accuracy: 0.9206
# Epoch 39/50
# 34799/34799 [==============================] - 21s 615us/sample - loss: 0.0143 - accuracy: 0.9955 - val_loss: 0.4073 - val_accuracy: 0.9252
# Epoch 40/50
# 34799/34799 [==============================] - 22s 626us/sample - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.4421 - val_accuracy: 0.9213
# Epoch 41/50
# 34799/34799 [==============================] - 26s 738us/sample - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.4097 - val_accuracy: 0.9227
# Epoch 42/50
# 34799/34799 [==============================] - 25s 731us/sample - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.4486 - val_accuracy: 0.9195
# Epoch 43/50
# 34799/34799 [==============================] - 25s 705us/sample - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.4293 - val_accuracy: 0.9186
# Epoch 44/50
# 34799/34799 [==============================] - 25s 716us/sample - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.4379 - val_accuracy: 0.9231
# Epoch 45/50
# 34799/34799 [==============================] - 25s 726us/sample - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.4613 - val_accuracy: 0.9150
# Epoch 46/50
# 34799/34799 [==============================] - 26s 736us/sample - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.3547 - val_accuracy: 0.9333
# Epoch 47/50
# 34799/34799 [==============================] - 25s 715us/sample - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.4760 - val_accuracy: 0.9211
# Epoch 48/50
# 34799/34799 [==============================] - 26s 754us/sample - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.4583 - val_accuracy: 0.9240
# Epoch 49/50
# 34799/34799 [==============================] - 23s 668us/sample - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.4335 - val_accuracy: 0.9159
# Epoch 50/50
# 34799/34799 [==============================] - 22s 633us/sample - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.5138 - val_accuracy: 0.9111

# %% [markdown]
# ### ASSESS TRAINED CNN MODEL PERFORMANCE

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/12630 [==============================] - 2s 189us/sample - loss: 0.9540 - accuracy: 0.9013
# Test Accuracy: 0.9013460278511047

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation loss')
plt.title('Training an Validation loss')
# Out:
# Text(0.5, 1.0, 'Training an Validation loss')

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'ro', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label = 'Validation accuracy')
plt.title('Training an Validation accuracy')
# Out:
# Text(0.5, 1.0, 'Training an Validation accuracy')

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
